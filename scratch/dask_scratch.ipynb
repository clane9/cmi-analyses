# %%
# !hostname
# Out:
# r004.ib.bridges2.psc.edu

# %%
from pathlib import Path

import dask
from dask import distributed
from dask import dataframe as dd

# %%
cluster = distributed.LocalCluster(
    n_workers=8,
    memory_limit="2GB",
    processes=True,
)
# Out:
# 2022-11-08 16:59:13,029 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3mdqi305', purging

# %%
client = distributed.Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:34905' processes=8 threads=8, memory=14.90 GiB>

# %%
root = "data"
nrows = 10000
nelem = 100

# %%
datadir = Path(root) / f"nrows-{nrows}_nelem-{nelem}"
attrib = dd.read_parquet(datadir / "attrib")
arrays = dd.read_parquet(datadir / "arrays")

# %%
threshold = 0.1
filtered = attrib.query(f"attrib < {threshold:.6f}")

# %%
joined = filtered.join(arrays)

# %%
joined.compute()
# Out:
#         attrib                                              array
# 10    0.063032  [-0.2903152213345372, -0.4553056473527136, 0.6...
# 24    0.021484  [0.5661824135291066, 0.5266973885062879, -0.61...
# 25    0.077082  [1.199005598780342, -0.5080641547239533, 0.059...
# 45    0.044312  [0.02722805369574031, -0.2829570982878555, 0.7...
# 49    0.082568  [1.2993175698137651, -1.869902989631917, 1.304...
# ...        ...                                                ...
# 9959  0.024942  [-1.1133449246341478, 1.0625067500480316, -0.5...
# 9968  0.038829  [1.2050571578020237, -0.0007325107955713086, -...
# 9988  0.069834  [-0.7074679523853701, 0.9882231786035628, -1.5...
# 9993  0.006232  [-0.7619140767013977, 0.07842396030474355, -1....
# 9998  0.058394  [0.42292788671437365, -2.42914788293689, -0.56...
#
# [1015 rows x 2 columns]
